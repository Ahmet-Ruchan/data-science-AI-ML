# %%
###SÜTUN GRAFİK (BAR PLOT)
import seaborn as sns
import pandas as pd

diamonds = sns.load_dataset('diamonds')
df = diamonds.copy()

print(sns.barplot(x = "cut", y = df.cut.index, data = df))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
import seaborn as sns
import pandas as pd

diamonds = sns.load_dataset('diamonds')
df = diamonds.copy()

print(df["cut"].value_counts().plot.barh().set_title("Class Frequencies of the Cut Variable"))
# Out:
# Text(0.5, 1.0, 'Class Frequencies of the Cut Variable')

# %%
import seaborn as sns
import pandas as pd
from pandas.api.types import is_categorical_dtype

diamonds = sns.load_dataset('diamonds')
df = diamonds.copy()

cut_categories = ["Fair", "Good", "Very Good", "Premium", "Ideal"]
df.cut = df.cut.astype(pd.CategoricalDtype(categories = cut_categories, ordered = True))
print(df.head())

sns.catplot(x = "cut", y = "price", data = df)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
import seaborn as sns
import pandas as pd
from pandas.api.types import is_categorical_dtype

diamonds = sns.load_dataset('diamonds')
df = diamonds.copy()

cut_categories = ["Fair", "Good", "Very Good", "Premium", "Ideal"]
df.cut = df.cut.astype(pd.CategoricalDtype(categories = cut_categories, ordered = True))

sns.barplot(x = "cut", y = "price", hue = "color", data = df)
